# %% [markdown]
# ___
# ## __Проект «Модель кредитного риск-менеджмента»__
# ___

# %% [markdown]
# ### __2-я часть - Тестирование модели__ :
# - файл: __`part_2_test_model.ipynb`__

# %% [markdown]
# ---
# ### __Структура файла__

# %% [markdown]
# ---
# * __Основная часть__
#     * Загрузка модели из файла
# ---
# * __Проверка загруженной модели, тестирование на выборках из исходных данных__
#     * Подготовка датасета с примерами для тестировани (на одном файле с исходными данными)
# 	* Тестирование модели (примерах из одного файла __`test_data/test_data.pq`__)
#        * Результаты предсказаний записываются в файл __`test_data/prediction_results.csv`__
# 	* Полный цикл тестирования:
# 		* Чтение всех файлов с train-данными
# 		* Подготовка примеров для тестирования модели
#         * Запись примеров в parquet-файл
# 		* Предсказание.

# %%
import pandas as pd
import numpy as np
import os
import time
from datetime import datetime

import dill
import dask.dataframe as dd

from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, mean_absolute_error, roc_curve, auc

# %%
# %matplotlib inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

import warnings
from sklearn.exceptions import FitFailedWarning

# warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")
warnings.filterwarnings("ignore", message="This Pipeline instance is not fitted yet")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.width', 1000)

RANDOM_STATE = 42
TEST_SIZE = 0.3
MODEL_TUNING_TIME_LIMIT = 1800  # 30 минут в секундах
# IS_DEBUG = False
# -----------------------------------------------------------------------------------------------------------------
# Глобальные параметры (переменные)
# Пути к названия файлов с данными
PATH_TO_DATA_TRAIN = 'train_data/'
PATH_TO_DATA_TEST  = 'test_data/'
FILE_TRAIN_TARGET  = 'train_target.csv'
FINAL_DATASET      = 'final_dataset.pq'

s_bold = '\033[1m'

# %% [markdown]
# #### Чтение одного файла данных parquet

# %%
# Загрузка одного файла данных parquet
def read_dataset_one_file(a_filename, is_debug=False, is_memory_optimize=False):
    
    if not os.path.exists(a_filename):
        print(f'Файл {a_filename} не найден!')
        return None, None
        
    if is_debug:
        print(f'Чтение одного файла ... {a_filename}')
    
    time_start = time.time()
        
    df_temp = dd.read_parquet(a_filename)
    df_temp = df_temp.compute()

    # сброс индекса
    df_temp.reset_index(drop=True, inplace=True)
    
    if is_memory_optimize:    # оптимизация числовых типов данных
        memory_usage_before = get_memory_usage(df_temp, False)
        optimize_numeric(df_temp, is_debug)
        memory_usage_after = get_memory_usage(df_temp, False)
        if is_debug:
            print(f'\tОбъем памяти (ДО оптимизации типов данных и ПОСЛЕ):\t {round(memory_usage_before, 3)} Гб >> {round(memory_usage_after, 3)} Гб')

    time_read = round(time.time() - time_start, 2)
    if is_debug:
        print(f'Чтение завершено:\n\tОбщее время чтения и обработки = {time_read:.1f} сек;   Размер = {df_temp.shape}')
    
    return df_temp, time_read

# %% [markdown]
# #### Запись датасета в файл

# %%
# Запись датасета в файл
def save_dataset_to_file(a_df, a_path=PATH_TO_DATA_TEST, a_file=FINAL_DATASET):

    file_full_name = a_path + a_file
    print(f'Запись файла {file_full_name}...')
    
    time_start = time.time()
    a_df.to_parquet(file_full_name, index=False)
    
    time_save = time.time() - time_start
    print(f'Файл успешно записан; время записи = {time_save:.1f} сек\n')

# %% [markdown]
# #### Загрузка модели из файла

# %%
# Загрузка модели из файла
def load_model(filename='credit_risk_management_prediction_model.pkl'):
    s_folder = 'models/'
    filename = f'{s_folder}{filename}'
    
    with open(filename, 'rb') as file:
        pipe_model_loaded = dill.load(file)    
        return pipe_model_loaded

# %% [markdown]
# #### Получение объема памяти датафрейма

# %%
# Объем памяти датафрейма
def get_memory_usage(a_df, is_debug=True):
    memory_size = a_df.memory_usage(index=True).sum() / 10**9
    if is_debug:
        print(f"Объем памяти датафрейма: {round(memory_size, 3)} Гб")
    return memory_size

# %% [markdown]
# #### Оптимизация числовых типов данных датафрейма

# %%
# оптимизация чиловых типов данных
def optimize_numeric(a_df, is_debug=True):
    
    cols_int   = a_df.select_dtypes(include=['int']).columns
    cols_float = a_df.select_dtypes(include=['float']).columns
        # print(f'columns integer = {len(cols_int)}:\t', cols_int)
        # print(f'columns float = {len(cols_float)}:\t', cols_float)
    time_start = time.time()
   
    for col in cols_int:
        a_df[col] = pd.to_numeric( a_df[col], downcast='integer')

    for col in a_df.select_dtypes(include=['int', 'float']).columns:
        a_df[col] = pd.to_numeric( a_df[col], downcast='float')

    time_optim = time.time() - time_start
    
    if is_debug:
        print(f'\tОптимизация типов данных завершена; время оптимизации = {time_optim:.1f} сек')
        
    return a_df

# %% [markdown]
# #### Формирование датасета с примерами для тестирования модели (с балансом классов 0 и 1)

# %%
# Формирование датасета с примерами для тестирования модели (с балансом классов 0 и 1)
def prepare_test_dataset(df_source_data, df_target, n_samples_per_class=1000):
    """
    Формирование тестового датасета с балансом классов
    
    Parameters:
    -----------
        df_source_data : DataFrame
            Исходный датафрейм с признаками (может содержать несколько записей на один id)
        df_target : DataFrame
            Датафрейм с id и целевой переменной flag
        n_samples_per_class : int
            Количество примеров для каждого класса (по умолчанию 1000)
        
    Returns:
    --------
        df_test_features : DataFrame
            Датафрейм с признаками для тестирования (структура как в df_source_data) + столбец target
        df_test_answers : DataFrame
            Датафрейм с правильными ответами (id и flag)
    """
    
    # 1. Объединяем целевые метки с основным датафреймом
    df_merged = df_source_data.merge(df_target, on='id', how='inner')
    
    # 2. Разделяем по классам
    df_class_1 = df_merged[df_merged['flag'] == 1]
    df_class_0 = df_merged[df_merged['flag'] == 0]
    
    # 3. Получаем уникальные id для каждого класса
    unique_ids_1 = df_class_1['id'].unique()
    unique_ids_0 = df_class_0['id'].unique()
    
    print(f"Всего уникальных id с flag=1: {len(unique_ids_1)}")
    print(f"Всего уникальных id с flag=0: {len(unique_ids_0)}")
    
    # 4. Выбираем случайные id для каждого класса
    if len(unique_ids_1) < n_samples_per_class:
        print(f"Внимание: запрошено {n_samples_per_class} id с flag=1, но доступно только {len(unique_ids_1)}")
        selected_ids_1 = unique_ids_1
    else:
        selected_ids_1 = np.random.choice(unique_ids_1, n_samples_per_class, replace=False)
    
    if len(unique_ids_0) < n_samples_per_class:
        print(f"Внимание: запрошено {n_samples_per_class} id с flag=0, но доступно только {len(unique_ids_0)}")
        selected_ids_0 = unique_ids_0
    else:
        selected_ids_0 = np.random.choice(unique_ids_0, n_samples_per_class, replace=False)
    
    # 5. Отбираем все записи для выбранных id
    selected_ids = np.concatenate([selected_ids_1, selected_ids_0])
    df_test_features = df_merged[df_merged['id'].isin(selected_ids)].copy()
    
    # 6. Переименовываем 'flag' в 'target' и переставляем столбцы
    df_test_features = df_test_features.rename(columns={'flag': 'target'})
    
    # Создаем новый порядок столбцов: id, target, остальные столбцы
    columns_order = ['id', 'target'] + [col for col in df_test_features.columns if col not in ['id', 'target']]
    df_test_features = df_test_features[columns_order]
    
    # 7. Создаем датафрейм с правильными ответами (переименовываем для consistency)
    df_test_answers = df_target[df_target['id'].isin(selected_ids)].copy()
    df_test_answers = df_test_answers.rename(columns={'flag': 'target'})
    
    # 8. Статистика
    print(f"\nРезультат подготовки тестового датасета:")
    print(f"\tОтобрано уникальных id с target=1: {len(selected_ids_1)}")
    print(f"\tОтобрано уникальных id с target=0: {len(selected_ids_0)}")
    print(f"\n\tВсего записей в тестовом датафрейме: {len(df_test_features)}")
    print(f"\tВсего уникальных id в тестовых ответах: {len(df_test_answers)}")
    print(f"\nРаспределение target в тестовых признаках:")
    print(df_test_features['target'].value_counts().sort_index())
    
    return df_test_features, df_test_answers

# %% [markdown]
# #### Тестирование модели на готовых примерах

# %%
# Тестирование модели на готовых примерах
def test_model_predictions(model, 
                           data_samples, 
                           target_col='target', 
                           is_save_results_to_file=True):
    """
    Функция для тестирования модели на N * 2 случайных примерах с расчетом метрик
    
    Параметры:
        - model      : обученная модель
        - data       : DataFrame с данными
        - target_col : название целевой колонки
    
    Возвращает:
        - results    : DataFrame с предсказаниями
        - metrics    : словарь с метриками
    """
    #--------------------------------------------------------------------------------------------------
    if data_samples.empty:
        print('Нет примеров для тестирования!')
        return None, None
    
    # Деление данных x и y
    x_test = data_samples.drop(columns=[target_col])
    y_true = data_samples[target_col]

    print('x_test.shape, y_true.shape:', x_test.shape, y_true.shape)
    
    #--------------------------------------------------------------------------------------------------
    # Предсказание
    y_pred = model.predict(x_test)
    
    #  id для группировки
    if 'id' in data_samples.columns:
        
        # Группировка y_true по id (берем первое значение для каждого id)
        y_true_grouped = data_samples.groupby('id')[target_col].first()
        
        # Проверка соответствия размеров
        print(f'После группировки: y_true_grouped={y_true_grouped.shape}, y_pred={len(y_pred)}')
        
        # Если все еще не совпадают, выравнивание по минимальному размеру
        if len(y_true_grouped) != len(y_pred):
            min_len = min(len(y_true_grouped), len(y_pred))
            y_true_grouped = y_true_grouped.iloc[:min_len]
            y_pred = y_pred[:min_len]
            print(f'После выравнивания: y_true_grouped={len(y_true_grouped)}, y_pred={len(y_pred)}')
    else:
        # Если нет колонки 'id', просто выравниваем по минимальному размеру
        min_len = min(len(y_true), len(y_pred))
        y_true_grouped = y_true.iloc[:min_len]
        y_pred = y_pred[:min_len]
        print(f'Выравнивание без ID: y_true_grouped={len(y_true_grouped)}, y_pred={len(y_pred)}')

    #--------------------------------------------------------------------------------------------------
    # Проверка возможности расчета roc_auc
    roc_auc = None
    if hasattr(model, 'predict_proba'):
        try:
            y_proba = model.predict_proba(x_test)[:, 1]
            
            # группирока y_proba, если нужно
            if 'id' in data_samples.columns and len(y_proba) != len(y_true_grouped):
                min_len = min(len(y_true_grouped), len(y_proba))    # Если y_proba имеет другой размер, тоже группировка
                y_proba = y_proba[:min_len]
                y_true_for_proba = y_true_grouped.iloc[:min_len]
            else:
                y_true_for_proba = y_true_grouped
                
            roc_auc = roc_auc_score(y_true_for_proba, y_proba)
        except Exception as e:
            print(f'Ошибка расчета ROC-AUC: {e}')
    
    # Расчет метрики с группированными данными
    # accuracy = accuracy_score(y_true_grouped, y_pred)
    
    #--------------------------------------------------------------------------------------------------
    # DataFrame с результатами тестирования
    results = pd.DataFrame({
        'y_valid':    y_true_grouped,
        'y_predict':  y_pred,
        'is_correct': (y_true_grouped == y_pred).astype(int)
    })
    
    # Добавление столбца id
    if 'id' in data_samples.columns:
        results['id'] = y_true_grouped.index.astype(int)
    
    # Добавление столбца с вероятностью
    if hasattr(model, 'predict_proba') and 'y_proba' in locals():
        results['prediction_prob'] = y_proba[:len(results)]  # Обрезаю до нужного размера

    results.reset_index(drop=True, inplace=True)
    
    # Метрики и количество примеров
    metrics = {
        # 'accuracy': accuracy,
        'roc_auc': roc_auc,
        'n_samples': len(results)
    }

    #--------------------------------------------------------------------------------------------------
    # Запись результатов предсказаний в файл
    if is_save_results_to_file:
        results.to_csv(PATH_TO_DATA_TEST + 'prediction_results.csv', index=False)
        print(f'Результаты тестирования записаны в файл: "{PATH_TO_DATA_TEST + 'prediction_results.csv'}"')
    
    #--------------------------------------------------------------------------------------------------
    # Вывод результатов
    print('-' * 100)
    print(f'\nРезультаты тестирования на {len(results)} примерах:')
    # print(f'\tAccuracy: {accuracy:.6f}')
    
    if roc_auc is not None:
        print(f'\troc_auc: {roc_auc:.6f}\n')
    print('-' * 100)
    
    return results, metrics

# %% [markdown]
# #### Подготовка одного файла с сырыми данными для тестирования модели - выжимка из тренировочных файлов

# %%
# Подготовка одного файла с сырыми данными для тестирования модели - выжимка из тренировочных файлов
# + тестирование модели на каждом из файлов
def prepare_file_for_test_predict(n_files = 2, n_samples = 1000, pipe_model = None):
    """
    # Подготовка файла с данными для тестирования
        # перебор n_files файлов c train-данными
        # подготовка по каждому файлу датсета с примерами (на каждый класс - по n_samples примеров)
        # если нужно, то тестирование предсказаний модели для каждого датасета (pipe_model is not None)
        # запись всех тестовых датасетов в один parquet-файл 'test_data.pq'
    """    
    metrics_all_tests = []
    test_data_all = []
    df_test_data_all = None
    df_metrics_all_tests = None

    dataset_paths = sorted(
        [os.path.join( PATH_TO_DATA_TRAIN, filename) for filename in os.listdir( PATH_TO_DATA_TRAIN)
         if filename.startswith('train_data_') and filename.endswith('.pq')],
        key=lambda x: int(x.split('_')[-1].split('.')[0])
    )
    
    if len(dataset_paths) == 0:
        print(f'В папке {PATH_TO_DATA_TRAIN} не найдено файлов вида "train_data_*.pq"')
        return None

    file_name = PATH_TO_DATA_TRAIN + FILE_TRAIN_TARGET
    if not os.path.exists(file_name):
        print(f'Файл {file_name} ней найден!')
        return None

    n_files = max(0, n_files)
    chunks = dataset_paths[:n_files]

    for i, file_name in enumerate(chunks):
    # for i in range(n_files):
        print(f'file {i}:')
        #------------------------------------------------------------------------------------------------------------
        # чтение файла c train-данными
        # df_data_raw, time_read = read_dataset_one_file( PATH_TO_DATA_TRAIN + f'train_data_{i}.pq', 
        df_data_raw, time_read = read_dataset_one_file( file_name, 
                                                       is_debug=True, 
                                                       is_memory_optimize=True)
        df_target = pd.read_csv( PATH_TO_DATA_TRAIN + FILE_TRAIN_TARGET )   

        #------------------------------------------------------------------------------------------------------------
        # подготовка датсета с примерами (на каждый класс - по n_samples_per_class примеров)
        df_test_data, df_test_answers = prepare_test_dataset(df_data_raw, df_target, n_samples_per_class=5000)    
        test_data_all.append(df_test_data)  # ← СОБИРАЕМ данные

        #------------------------------------------------------------------------------------------------------------
        # тестирование модели
        if (pipe_model is not None):
            results, metrics = test_model_predictions(model=pipe_model, 
                                                      data_samples=df_test_data, target_col='target', 
                                                      is_save_results_to_file=False)
            # results, metrics = test_model_predictions(model=pipe_model_loaded['model'], 
                                                        # data_samples=df_test_data, target_col='target', 
                                                        # is_save_results_to_file=False)
            metrics_all_tests.append(metrics)

        #
        if df_test_data_all is None:
            df_test_data_all = df_test_data
        else:
            df_test_data_all = pd.concat( [df_test_data_all, df_test_data], ignore_index=True)
            # df_result = pd.concat( [df_result, df_temp_processed], ignore_index=True)
            
    # все данные в один датафрейм
    # df_test_data_all     = pd.concat(test_data_all, ignore_index=True)
    df_metrics_all_tests = pd.DataFrame(metrics_all_tests)
    
    # запись датасета со всеми примерами для тестирования в отдельный файл
    save_dataset_to_file( a_df=df_test_data_all, 
                          a_path=PATH_TO_DATA_TEST, 
                          a_file='test_data.pq')
    
    # результаты
    print('=' * 100)
    print(f"Объединенный датафрейм:\n\tРазмеры = {df_test_data_all.shape};\tЗаписан в файл: {PATH_TO_DATA_TEST + 'test_data.pq'}")
    
    if (pipe_model is not None):
        print(f"Метрики по файлам:")
        print(df_metrics_all_tests)
    
        print(f'По всем {len(df_metrics_all_tests)} файлам-примерам:\n\troc_auc mean = {df_metrics_all_tests.roc_auc.mean():.6f}')
        
    return df_metrics_all_tests #, df_test_data_all
    # return df_metrics_all_tests, df_test_data_all

# %% [markdown]
# ## Основная часть

# %% [markdown]
# ### Проверка. Загрузка модели из файла

# %%
# Проверка - Загрузка модели из файла
pipe_model_loaded = load_model('credit_risk_management_prediction_model.pkl')
pipe_model_loaded
# Out:
# {'model': Pipeline(steps=[('preprocessor',
#                   Pipeline(steps=[('data_preprocessing',
#                                    FunctionTransformer(func=<function data_preprocessing at 0x000001E4AEA33C40>)),
#                                   ('selector_features',
#                                    FeatureSelectorTransformer(all_top_features=['ratio_overdue_loans3060',
#                                                                                 'ratio_overdue_loans90',
#                                                                                 'ratio_overdue_loans6090',
#                                                                                 'ratio_loans_overdue_total',
#                                                                                 'ratio_overdue_loans530',
#                                                                                 'count_ov...
#                                                               max_cat_threshold=None,
#                                                               max_cat_to_onehot=None,
#                                                               max_delta_step=None,
#                                                               max_depth=9,
#                                                               max_leaves=None,
#                                                               min_child_weight=90,
#                                                               missing=nan,
#                                                               monotone_constraints=None,
#                                                               multi_strategy=None,
#                                                               n_estimators=1000,
#                                                               n_jobs=-1,
#                                                               num_parallel_tree=None,
#                                                               random_state=42, ...)),
#                                                ('CatBoost_optional',
#                                                 <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>)],
#                                    n_jobs=-1, voting='soft',
#                                    weights=[1, 1, 1]))]),
#  'metadata': {'name': 'Credit risk management prediction model',
#   'author': 'Andrei Mishenkov',
#   'version': 1.0,
#   'date': '2025-10-22 22:43:21',
#   'type': 'VotingClassifier',
#   'roc_auc': 0.798823}}

# %%
pipe_model_loaded['model']
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('data_preprocessing',
#                                   FunctionTransformer(func=<function data_preprocessing at 0x000001E4AEA33C40>)),
#                                  ('selector_features',
#                                   FeatureSelectorTransformer(all_top_features=['ratio_overdue_loans3060',
#                                                                                'ratio_overdue_loans90',
#                                                                                'ratio_overdue_loans6090',
#                                                                                'ratio_loans_overdue_total',
#                                                                                'ratio_overdue_loans530',
#                                                                                'count_ov...
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=9,
#                                                              max_leaves=None,
#                                                              min_child_weight=90,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=1000,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None,
#                                                              random_state=42, ...)),
#                                               ('CatBoost_optional',
#                                                <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>)],
#                                   n_jobs=-1, voting='soft',
#                                   weights=[1, 1, 1]))])

# %%
pipe_model_loaded['model'].named_steps['classifier']
# Out:
# VotingClassifier(estimators=[('LGBMCLassifier objective_fast',
#                               LGBMClassifier(colsample_bytree=0.7248044994766626,
#                                              is_unbalance=False,
#                                              learning_rate=0.02424703456435817,
#                                              max_depth=7, min_child_samples=70,
#                                              n_estimators=1650, n_jobs=-1,
#                                              num_leaves=59, random_state=42,
#                                              reg_alpha=0.738924554711979,
#                                              reg_lambda=0.7647132769869521,
#                                              subsample=0.729283573622419,
#                                              verbose=...
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=9,
#                                             max_leaves=None,
#                                             min_child_weight=90, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=1000, n_jobs=-1,
#                                             num_parallel_tree=None,
#                                             random_state=42, ...)),
#                              ('CatBoost_optional',
#                               <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>)],
#                  n_jobs=-1, voting='soft', weights=[1, 1, 1])

# %% [markdown]
# #### Проверка атрибутов пайплайна и модели

# %%
# Проверка, что модель загружена корректно
print(f'Тип модели: {type(pipe_model_loaded['model'])}')
print(f'Тип классификатора: {type(pipe_model_loaded['model'].named_steps['classifier']).__name__}')

attr = [attr for attr in dir(pipe_model_loaded['model']) if 'fit' in attr or 'class' in attr]
# print(f"\nАтрибуты обученности: {attr}")
# Проверка атрибутов, указывающих на обучение
if False:
    print("Проверка атрибутов:")
    for item in attr:
        print(f"\thasattr(model, '{item:<22}'): {hasattr(pipe_model_loaded['model'], item)}")
# Out:
# Тип модели: <class 'sklearn.pipeline.Pipeline'>
# Тип классификатора: VotingClassifier

# %% [markdown]
# #### Получение параметров загруженной модели

# %%
model_params = pipe_model_loaded['model'].named_steps['classifier'].get_params()
print('Параметры - список:')
print(f'model_params = {model_params}\n')

# Получение параметров загруженной модели
model_params = pipe_model_loaded['model'].named_steps['classifier'].get_params()

df_params = pd.DataFrame({
    'Параметр': model_params.keys(),
    'Значение': model_params.values()
})

print('Параметры - таблица:')
print(df_params)
# Out:
# Параметры - список:
# model_params = {'estimators': [('LGBMCLassifier objective_fast', LGBMClassifier(colsample_bytree=0.7248044994766626, is_unbalance=False,
#                learning_rate=0.02424703456435817, max_depth=7,
#                min_child_samples=70, n_estimators=1650, n_jobs=-1,
#                num_leaves=59, random_state=42, reg_alpha=0.738924554711979,
#                reg_lambda=0.7647132769869521, subsample=0.729283573622419,
#                verbose=-1)), ('XGBClassifier objective_xgb_fast', XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8346382656042973, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.033019071561003456,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=90, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=-1,
#               num_parallel_tree=None, random_state=42, ...)), ('CatBoost_optional', <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>)], 'flatten_transform': True, 'n_jobs': -1, 'verbose': False, 'voting': 'soft', 'weights': [1, 1, 1], 'LGBMCLassifier objective_fast': LGBMClassifier(colsample_bytree=0.7248044994766626, is_unbalance=False,
#                learning_rate=0.02424703456435817, max_depth=7,
#                min_child_samples=70, n_estimators=1650, n_jobs=-1,
#                num_leaves=59, random_state=42, reg_alpha=0.738924554711979,
#                reg_lambda=0.7647132769869521, subsample=0.729283573622419,
#                verbose=-1), 'XGBClassifier objective_xgb_fast': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8346382656042973, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.033019071561003456,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=90, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=-1,
#               num_parallel_tree=None, random_state=42, ...), 'CatBoost_optional': <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>, 'LGBMCLassifier objective_fast__boosting_type': 'gbdt', 'LGBMCLassifier objective_fast__class_weight': None, 'LGBMCLassifier objective_fast__colsample_bytree': 0.7248044994766626, 'LGBMCLassifier objective_fast__importance_type': 'split', 'LGBMCLassifier objective_fast__learning_rate': 0.02424703456435817, 'LGBMCLassifier objective_fast__max_depth': 7, 'LGBMCLassifier objective_fast__min_child_samples': 70, 'LGBMCLassifier objective_fast__min_child_weight': 0.001, 'LGBMCLassifier objective_fast__min_split_gain': 0.0, 'LGBMCLassifier objective_fast__n_estimators': 1650, 'LGBMCLassifier objective_fast__n_jobs': -1, 'LGBMCLassifier objective_fast__num_leaves': 59, 'LGBMCLassifier objective_fast__objective': None, 'LGBMCLassifier objective_fast__random_state': 42, 'LGBMCLassifier objective_fast__reg_alpha': 0.738924554711979, 'LGBMCLassifier objective_fast__reg_lambda': 0.7647132769869521, 'LGBMCLassifier objective_fast__subsample': 0.729283573622419, 'LGBMCLassifier objective_fast__subsample_for_bin': 200000, 'LGBMCLassifier objective_fast__subsample_freq': 0, 'LGBMCLassifier objective_fast__is_unbalance': False, 'LGBMCLassifier objective_fast__verbose': -1, 'XGBClassifier objective_xgb_fast__objective': 'binary:logistic', 'XGBClassifier objective_xgb_fast__base_score': None, 'XGBClassifier objective_xgb_fast__booster': None, 'XGBClassifier objective_xgb_fast__callbacks': None, 'XGBClassifier objective_xgb_fast__colsample_bylevel': None, 'XGBClassifier objective_xgb_fast__colsample_bynode': None, 'XGBClassifier objective_xgb_fast__colsample_bytree': 0.8346382656042973, 'XGBClassifier objective_xgb_fast__device': None, 'XGBClassifier objective_xgb_fast__early_stopping_rounds': None, 'XGBClassifier objective_xgb_fast__enable_categorical': False, 'XGBClassifier objective_xgb_fast__eval_metric': 'logloss', 'XGBClassifier objective_xgb_fast__feature_types': None, 'XGBClassifier objective_xgb_fast__gamma': None, 'XGBClassifier objective_xgb_fast__grow_policy': None, 'XGBClassifier objective_xgb_fast__importance_type': None, 'XGBClassifier objective_xgb_fast__interaction_constraints': None, 'XGBClassifier objective_xgb_fast__learning_rate': 0.033019071561003456, 'XGBClassifier objective_xgb_fast__max_bin': None, 'XGBClassifier objective_xgb_fast__max_cat_threshold': None, 'XGBClassifier objective_xgb_fast__max_cat_to_onehot': None, 'XGBClassifier objective_xgb_fast__max_delta_step': None, 'XGBClassifier objective_xgb_fast__max_depth': 9, 'XGBClassifier objective_xgb_fast__max_leaves': None, 'XGBClassifier objective_xgb_fast__min_child_weight': 90, 'XGBClassifier objective_xgb_fast__missing': nan, 'XGBClassifier objective_xgb_fast__monotone_constraints': None, 'XGBClassifier objective_xgb_fast__multi_strategy': None, 'XGBClassifier objective_xgb_fast__n_estimators': 1000, 'XGBClassifier objective_xgb_fast__n_jobs': -1, 'XGBClassifier objective_xgb_fast__num_parallel_tree': None, 'XGBClassifier objective_xgb_fast__random_state': 42, 'XGBClassifier objective_xgb_fast__reg_alpha': 0.5181540185095732, 'XGBClassifier objective_xgb_fast__reg_lambda': 0.6752815102869354, 'XGBClassifier objective_xgb_fast__sampling_method': None, 'XGBClassifier objective_xgb_fast__scale_pos_weight': None, 'XGBClassifier objective_xgb_fast__subsample': 0.7665473841441554, 'XGBClassifier objective_xgb_fast__tree_method': None, 'XGBClassifier objective_xgb_fast__validate_parameters': None, 'XGBClassifier objective_xgb_fast__verbosity': 0, 'CatBoost_optional__iterations': 800, 'CatBoost_optional__learning_rate': 0.07, 'CatBoost_optional__depth': 6, 'CatBoost_optional__verbose': False, 'CatBoost_optional__subsample': 0.8, 'CatBoost_optional__colsample_bylevel': 0.8, 'CatBoost_optional__random_state': 42}
#
# Параметры - таблица:
#                                                      Параметр                                                                                             Значение
# 0                                                  estimators  [(LGBMCLassifier objective_fast, LGBMClassifier(colsample_bytree=0.7248044994766626, is_unbalanc...
# 1                                           flatten_transform                                                                                                 True
# 2                                                      n_jobs                                                                                                   -1
# 3                                                     verbose                                                                                                False
# 4                                                      voting                                                                                                 soft
# 5                                                     weights                                                                                            [1, 1, 1]
# 6                               LGBMCLassifier objective_fast  LGBMClassifier(colsample_bytree=0.7248044994766626, is_unbalance=False,\n               learning...
# 7                            XGBClassifier objective_xgb_fast  XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=No...
# 8                                           CatBoost_optional                                      <catboost.core.CatBoostClassifier object at 0x000001E4AFBC8890>
# 9                LGBMCLassifier objective_fast__boosting_type                                                                                                 gbdt
# 10                LGBMCLassifier objective_fast__class_weight                                                                                                 None
# 11            LGBMCLassifier objective_fast__colsample_bytree                                                                                             0.724804
# 12             LGBMCLassifier objective_fast__importance_type                                                                                                split
# 13               LGBMCLassifier objective_fast__learning_rate                                                                                             0.024247
# 14                   LGBMCLassifier objective_fast__max_depth                                                                                                    7
# 15           LGBMCLassifier objective_fast__min_child_samples                                                                                                   70
# 16            LGBMCLassifier objective_fast__min_child_weight                                                                                                0.001
# 17              LGBMCLassifier objective_fast__min_split_gain                                                                                                  0.0
# 18                LGBMCLassifier objective_fast__n_estimators                                                                                                 1650
# 19                      LGBMCLassifier objective_fast__n_jobs                                                                                                   -1
# 20                  LGBMCLassifier objective_fast__num_leaves                                                                                                   59
# 21                   LGBMCLassifier objective_fast__objective                                                                                                 None
# 22                LGBMCLassifier objective_fast__random_state                                                                                                   42
# 23                   LGBMCLassifier objective_fast__reg_alpha                                                                                             0.738925
# 24                  LGBMCLassifier objective_fast__reg_lambda                                                                                             0.764713
# 25                   LGBMCLassifier objective_fast__subsample                                                                                             0.729284
# 26           LGBMCLassifier objective_fast__subsample_for_bin                                                                                               200000
# 27              LGBMCLassifier objective_fast__subsample_freq                                                                                                    0
# 28                LGBMCLassifier objective_fast__is_unbalance                                                                                                False
# 29                     LGBMCLassifier objective_fast__verbose                                                                                                   -1
# 30                XGBClassifier objective_xgb_fast__objective                                                                                      binary:logistic
# 31               XGBClassifier objective_xgb_fast__base_score                                                                                                 None
# 32                  XGBClassifier objective_xgb_fast__booster                                                                                                 None
# 33                XGBClassifier objective_xgb_fast__callbacks                                                                                                 None
# 34        XGBClassifier objective_xgb_fast__colsample_bylevel                                                                                                 None
# 35         XGBClassifier objective_xgb_fast__colsample_bynode                                                                                                 None
# 36         XGBClassifier objective_xgb_fast__colsample_bytree                                                                                             0.834638
# 37                   XGBClassifier objective_xgb_fast__device                                                                                                 None
# 38    XGBClassifier objective_xgb_fast__early_stopping_rounds                                                                                                 None
# 39       XGBClassifier objective_xgb_fast__enable_categorical                                                                                                False
# 40              XGBClassifier objective_xgb_fast__eval_metric                                                                                              logloss
# 41            XGBClassifier objective_xgb_fast__feature_types                                                                                                 None
# 42                    XGBClassifier objective_xgb_fast__gamma                                                                                                 None
# 43              XGBClassifier objective_xgb_fast__grow_policy                                                                                                 None
# 44          XGBClassifier objective_xgb_fast__importance_type                                                                                                 None
# 45  XGBClassifier objective_xgb_fast__interaction_constraints                                                                                                 None
# 46            XGBClassifier objective_xgb_fast__learning_rate                                                                                             0.033019
# 47                  XGBClassifier objective_xgb_fast__max_bin                                                                                                 None
# 48        XGBClassifier objective_xgb_fast__max_cat_threshold                                                                                                 None
# 49        XGBClassifier objective_xgb_fast__max_cat_to_onehot                                                                                                 None
# 50           XGBClassifier objective_xgb_fast__max_delta_step                                                                                                 None
# 51                XGBClassifier objective_xgb_fast__max_depth                                                                                                    9
# 52               XGBClassifier objective_xgb_fast__max_leaves                                                                                                 None
# 53         XGBClassifier objective_xgb_fast__min_child_weight                                                                                                   90
# 54                  XGBClassifier objective_xgb_fast__missing                                                                                                  NaN
# 55     XGBClassifier objective_xgb_fast__monotone_constraints                                                                                                 None
# 56           XGBClassifier objective_xgb_fast__multi_strategy                                                                                                 None
# 57             XGBClassifier objective_xgb_fast__n_estimators                                                                                                 1000
# 58                   XGBClassifier objective_xgb_fast__n_jobs                                                                                                   -1
# 59        XGBClassifier objective_xgb_fast__num_parallel_tree                                                                                                 None
# 60             XGBClassifier objective_xgb_fast__random_state                                                                                                   42
# 61                XGBClassifier objective_xgb_fast__reg_alpha                                                                                             0.518154
# 62               XGBClassifier objective_xgb_fast__reg_lambda                                                                                             0.675282
# 63          XGBClassifier objective_xgb_fast__sampling_method                                                                                                 None
# 64         XGBClassifier objective_xgb_fast__scale_pos_weight                                                                                                 None
# 65                XGBClassifier objective_xgb_fast__subsample                                                                                             0.766547
# 66              XGBClassifier objective_xgb_fast__tree_method                                                                                                 None
# 67      XGBClassifier objective_xgb_fast__validate_parameters                                                                                                 None
# 68                XGBClassifier objective_xgb_fast__verbosity                                                                                                    0
# 69                              CatBoost_optional__iterations                                                                                                  800
# 70                           CatBoost_optional__learning_rate                                                                                                 0.07
# 71                                   CatBoost_optional__depth                                                                                                    6
# 72                                 CatBoost_optional__verbose                                                                                                False
# 73                               CatBoost_optional__subsample                                                                                                  0.8
# 74                       CatBoost_optional__colsample_bylevel                                                                                                  0.8
# 75                            CatBoost_optional__random_state                                                                                                   42

# %% [markdown]
# #### Тестирование модели на примерах из готового файла
# - `test_data.pq` (выжимка из файлов с train-данными)

# %%
# Загрузка файла с данными для тестирования модели 
file_name = PATH_TO_DATA_TEST + 'test_data.pq'

df_test_data, time_read = read_dataset_one_file( 
                                                    a_filename=file_name, 
                                                    is_debug=True, 
                                                    is_memory_optimize=True
)
if df_test_data is not None:
    
    # file_name = PATH_TO_DATA_TRAIN + FILE_TRAIN_TARGET
    # if os.path.exists(file_name):
        
    #     print(f'Чтение файла {file_name}...')
    #     df_target = pd.read_csv( file_name )
    #     optimize_numeric(df_target, is_debug=False)
        
    # Тестирование модели на примерах из одного файла
    results, metrics = test_model_predictions(
                                                model        = pipe_model_loaded['model'], 
                                                data_samples = df_test_data, 
                                                target_col   = 'target',
                                                is_save_results_to_file = True
    )
    
    print(metrics)
    print('\nПример результатов предсказаний:')
    print(results[results['y_valid'] == 1].sort_values('is_correct', ascending=False).head())
        
    # else:
    #     print(f'Файл {file_name} не найден!')
# Out:
# Чтение одного файла ... test_data/test_data.pq
# 	Оптимизация типов данных завершена; время оптимизации = 0.1 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 0.074 Гб >> 0.066 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 0.4 сек;   Размер = (1021346, 62)
# x_test.shape, y_true.shape: (1021346, 61) (1021346,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (1021346, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (1021346, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (120000, 408)
# 		ohe - 5 - df_total - merge; df_total.shape = (120000, 428)
# 	ohe_source_columns завершен:	   Время выполнения = 7.3s;	   shape = (120000, 428)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (120000, 369)
# После группировки: y_true_grouped=(120000,), y_pred=120000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (1021346, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (1021346, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (120000, 408)
# 		ohe - 5 - df_total - merge; df_total.shape = (120000, 428)
# 	ohe_source_columns завершен:	   Время выполнения = 7.9s;	   shape = (120000, 428)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (120000, 369)
# Результаты тестирования записаны в файл: "test_data/prediction_results.csv"
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 120000 примерах:
# 	roc_auc: 0.779685
#
# ----------------------------------------------------------------------------------------------------
# {'roc_auc': 0.77968487, 'n_samples': 120000}
#
# Пример результатов предсказаний:
#         y_valid  y_predict  is_correct       id  prediction_prob
# 38298         1          1           1   960526         0.537869
# 39649         1          1           1   992022         0.545961
# 108795        1          1           1  2720286         0.652559
# 112401        1          1           1  2805451         0.535767
# 61889         1          1           1  1547560         0.507233

# %%
results.head(3)
# Out:
#    y_valid  y_predict  is_correct   id  prediction_prob
# 0        1          0           0   20         0.099478
# 1        1          0           0  118         0.075861
# 2        1          0           0  120         0.072880

# %% [markdown]
# #### Полный цикл тестирования
# - Чтение всех файлов с train-данными
# - Подготовка примеров для тестирования модели
# - Запись примеров в файл `test_data.pq`
# - Предсказание для каждого файла в отдельности

# %%
# %%time
# Подготовка файла с данными для тестирования
    # перебор n_files файлов c train-данными
    # подготовка датсетов с примерами (на каждый класс - по n_samples примеров)
    # тестирование предсказания модели по каждому датасету (если это нужно, то pipe_model is not None)
    # запись тестовых датасетов в parquet-файл 'test_data.pq'

#--------------------------------------------------------------------------------------------------------------
# Запуск генерации примеров сразу с предсказанием по каждому файлу в отдельности
if True:
    df_metrics_all_tests = prepare_file_for_test_predict(
                                                            n_files = 12, 
                                                            n_samples = 5000, 
                                                            pipe_model = pipe_model_loaded['model']
    )
#--------------------------------------------------------------------------------------------------------------
# Запуск генерации примеров (без предсказаний, формируется только файл 'test_data.pq')
if False:
    _ = prepare_file_for_test_predict(
                                        n_files = 12, 
                                        n_samples = 5000, 
                                        pipe_model = None
    )
# Out:
# file 0:
# Чтение одного файла ... train_data/train_data_0.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.5 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 0.964 Гб >> 0.126 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 2.6 сек;   Размер = (1974724, 61)
# Всего уникальных id с flag=1: 7734
# Всего уникальных id с flag=0: 242266
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 76692
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    39342
# 1    37350
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (76692, 61) (76692,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (76692, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (76692, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 387)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 407)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 407)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (76692, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (76692, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 387)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 407)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 407)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.796494
#
# ----------------------------------------------------------------------------------------------------
# file 1:
# Чтение одного файла ... train_data/train_data_1.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.9 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.028 Гб >> 0.135 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.4 сек;   Размер = (2107305, 61)
# Всего уникальных id с flag=1: 8212
# Всего уникальных id с flag=0: 241788
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 80694
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    42372
# 1    38322
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (80694, 61) (80694,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (80694, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (80694, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 391)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 411)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 411)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (80694, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (80694, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 391)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 411)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 411)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.784387
#
# ----------------------------------------------------------------------------------------------------
# file 2:
# Чтение одного файла ... train_data/train_data_2.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.8 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.015 Гб >> 0.133 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 2.9 сек;   Размер = (2080508, 61)
# Всего уникальных id с flag=1: 8793
# Всего уникальных id с flag=0: 241207
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 81252
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    42258
# 1    38994
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (81252, 61) (81252,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (81252, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (81252, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 385)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 405)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 405)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (81252, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (81252, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 385)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 405)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 405)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.792126
#
# ----------------------------------------------------------------------------------------------------
# file 3:
# Чтение одного файла ... train_data/train_data_3.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.9 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.031 Гб >> 0.135 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.0 сек;   Размер = (2112592, 61)
# Всего уникальных id с flag=1: 9104
# Всего уникальных id с flag=0: 240896
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 82881
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    42912
# 1    39969
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (82881, 61) (82881,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (82881, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (82881, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 387)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 407)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 407)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (82881, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (82881, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 387)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 407)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 407)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.790854
#
# ----------------------------------------------------------------------------------------------------
# file 4:
# Чтение одного файла ... train_data/train_data_4.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.8 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.007 Гб >> 0.132 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 2.9 сек;   Размер = (2064110, 61)
# Всего уникальных id с flag=1: 10170
# Всего уникальных id с flag=0: 239830
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 79400
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    41066
# 1    38334
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (79400, 61) (79400,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (79400, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (79400, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 392)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 412)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 412)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (79400, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (79400, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 392)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 412)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 412)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.788033
#
# ----------------------------------------------------------------------------------------------------
# file 5:
# Чтение одного файла ... train_data/train_data_5.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.9 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.05 Гб >> 0.138 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.0 сек;   Размер = (2150908, 61)
# Всего уникальных id с flag=1: 9309
# Всего уникальных id с flag=0: 240691
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 83206
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    42595
# 1    40611
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (83206, 61) (83206,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (83206, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (83206, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 393)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 413)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 413)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (83206, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (83206, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 393)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 413)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 413)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.780748
#
# ----------------------------------------------------------------------------------------------------
# file 6:
# Чтение одного файла ... train_data/train_data_6.pq
# 	Оптимизация типов данных завершена; время оптимизации = 1.9 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.062 Гб >> 0.139 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.0 сек;   Размер = (2176452, 61)
# Всего уникальных id с flag=1: 9625
# Всего уникальных id с flag=0: 240375
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 83541
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    43183
# 1    40358
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (83541, 61) (83541,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (83541, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (83541, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 396)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 416)
# 	ohe_source_columns завершен:	   Время выполнения = 0.4s;	   shape = (10000, 416)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (83541, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (83541, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 396)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 416)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 416)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.771047
#
# ----------------------------------------------------------------------------------------------------
# file 7:
# Чтение одного файла ... train_data/train_data_7.pq
# 	Оптимизация типов данных завершена; время оптимизации = 2.0 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.084 Гб >> 0.142 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.0 сек;   Размер = (2222245, 61)
# Всего уникальных id с flag=1: 9373
# Всего уникальных id с flag=0: 240627
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 86662
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    44226
# 1    42436
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (86662, 61) (86662,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (86662, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (86662, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 392)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 412)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 412)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (86662, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (86662, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 392)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 412)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 412)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.774328
#
# ----------------------------------------------------------------------------------------------------
# file 8:
# Чтение одного файла ... train_data/train_data_8.pq
# 	Оптимизация типов данных завершена; время оптимизации = 2.0 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.094 Гб >> 0.144 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.0 сек;   Размер = (2242615, 61)
# Всего уникальных id с flag=1: 9431
# Всего уникальных id с flag=0: 240569
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 88857
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    44698
# 1    44159
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (88857, 61) (88857,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (88857, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (88857, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 393)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 413)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 413)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (88857, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (88857, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 393)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 413)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 413)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.770718
#
# ----------------------------------------------------------------------------------------------------
# file 9:
# Чтение одного файла ... train_data/train_data_9.pq
# 	Оптимизация типов данных завершена; время оптимизации = 2.0 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.115 Гб >> 0.146 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.1 сек;   Размер = (2284256, 61)
# Всего уникальных id с flag=1: 8284
# Всего уникальных id с flag=0: 241716
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 90737
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    45602
# 1    45135
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (90737, 61) (90737,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (90737, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (90737, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 394)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 414)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 414)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (90737, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (90737, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 394)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 414)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 414)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.779617
#
# ----------------------------------------------------------------------------------------------------
# file 10:
# Чтение одного файла ... train_data/train_data_10.pq
# 	Оптимизация типов данных завершена; время оптимизации = 2.2 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.121 Гб >> 0.147 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.3 сек;   Размер = (2296372, 61)
# Всего уникальных id с flag=1: 8434
# Всего уникальных id с flag=0: 241566
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 89786
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    45662
# 1    44124
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (89786, 61) (89786,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (89786, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (89786, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 398)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 418)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 418)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (89786, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (89786, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 398)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 418)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 418)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.766037
#
# ----------------------------------------------------------------------------------------------------
# file 11:
# Чтение одного файла ... train_data/train_data_11.pq
# 	Оптимизация типов данных завершена; время оптимизации = 2.3 сек
# 	Объем памяти (ДО оптимизации типов данных и ПОСЛЕ):	 1.196 Гб >> 0.157 Гб
# Чтение завершено:
# 	Общее время чтения и обработки = 3.7 сек;   Размер = (2450630, 61)
# Всего уникальных id с flag=1: 7973
# Всего уникальных id с flag=0: 242027
#
# Результат подготовки тестового датасета:
# 	Отобрано уникальных id с target=1: 5000
# 	Отобрано уникальных id с target=0: 5000
#
# 	Всего записей в тестовом датафрейме: 97638
# 	Всего уникальных id в тестовых ответах: 10000
#
# Распределение target в тестовых признаках:
# target
# 0    49149
# 1    48489
# Name: count, dtype: int64
# x_test.shape, y_true.shape: (97638, 61) (97638,)
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (97638, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (97638, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 396)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 416)
# 	ohe_source_columns завершен:	   Время выполнения = 0.5s;	   shape = (10000, 416)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# После группировки: y_true_grouped=(10000,), y_pred=10000
# ----------------------------------------------------------------------------------------------------
# Выполняется data_preprocessing ...
# 	Группировка данных по столбцу "rn"...
# 	Создание новых признаков ...
# 	Выполняется ohe_source_columns ...
# 		ohe - 1 - source df_ids shape = (97638, 1)
# 		ohe - 2 - fit
# 		ohe - 3 - transform; df_ids shape = (97638, 1)
# 		ohe - 4 - df_ids: group & sum; df_ids shape = (10000, 396)
# 		ohe - 5 - df_total - merge; df_total.shape = (10000, 416)
# 	ohe_source_columns завершен:	   Время выполнения = 0.6s;	   shape = (10000, 416)
# ----------------------------------------------------------------------------------------------------
# Выполняется FeatureSelectorTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется DynamicStandardScaler ... метод transform
# ----------------------------------------------------------------------------------------------------
# Выполняется LastStepTransformer ... метод transform
# ----------------------------------------------------------------------------------------------------
# Пайплайн успешно завершен
# Размер обработанного датасета: (10000, 369)
# ----------------------------------------------------------------------------------------------------
#
# Результаты тестирования на 10000 примерах:
# 	roc_auc: 0.765053
#
# ----------------------------------------------------------------------------------------------------
# Запись файла test_data/test_data.pq...
# Файл успешно записан; время записи = 0.8 сек
#
# ====================================================================================================
# Объединенный датафрейм:
# 	Размеры = (1021346, 62);	Записан в файл: test_data/test_data.pq
# Метрики по файлам:
#      roc_auc  n_samples
# 0   0.796494      10000
# 1   0.784387      10000
# 2   0.792126      10000
# 3   0.790854      10000
# 4   0.788033      10000
# 5   0.780748      10000
# 6   0.771047      10000
# 7   0.774328      10000
# 8   0.770718      10000
# 9   0.779617      10000
# 10  0.766037      10000
# 11  0.765053      10000
# По всем 12 файлам-примерам:
# 	roc_auc mean = 0.779953
# CPU times: total: 4min 1s
# Wall time: 1min 2s

# %%
if (df_metrics_all_tests is not None):
    print(f'По всем {len(df_metrics_all_tests)} файлам-примерам:\n\troc_auc mean = {df_metrics_all_tests.roc_auc.mean():.6f}')
# Out:
# По всем 12 файлам-примерам:
# 	roc_auc mean = 0.779953
